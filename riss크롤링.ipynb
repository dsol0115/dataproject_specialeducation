# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from selenium import webdriver
import time

riss_title = []

driver = webdriver.Chrome(executable_path=r'C:\Users\yundasol\Documents\Python Scripts\chromedriver.exe')
driver.implicitly_wait(3)

driver.get('http://www.riss.kr/index.do')
driver.find_element_by_css_selector('#basicQuery.it').send_keys('특수교육')  
driver.find_element_by_css_selector('.btn').click() 
driver.implicitly_wait(3)

##학위논문부터
driver.find_element_by_css_selector('.more').click() 
driver.implicitly_wait(3)
con=0
while(True):
    
    while(True):
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        title_list = soup.find_all('p', 'txt')

        for title in title_list:
            titles = title.text
            riss_title.append(titles)
            
        try:
            driver.find_element_by_css_selector('.num strong+a').click()
        except:
            break
        time.sleep(1)
       
    try:
        if(con==0):
            driver.find_element_by_css_selector('.passing > span:nth-child(3) > a').click()
            con=1
        else:
            driver.find_element_by_css_selector('.passing > span:nth-child(4) > a').click()  
    except:
        break
    time.sleep(1)

    
data = pd.DataFrame(riss_title)
data.to_csv('risscrawl.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-15d35ea8e999> in <module>
#       7 riss_title = []
#       8
# ----> 9 driver = webdriver.Chrome(executable_path=r'C:\Users\yundasol\Documents\Python Scripts\chromedriver.exe')
#      10 driver.implicitly_wait(3)
#      11
#
# ...
